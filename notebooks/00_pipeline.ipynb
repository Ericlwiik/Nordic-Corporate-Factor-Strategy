# %% [markdown]
# # NCFS — Nordic Corporate Bond Factor Strategy
#
# Walk-forward backtest pipeline implementing the SAFI framework with six factors:
# momentum, value, carry, quality, low-risk, and sentiment.
#
# **Pipeline**: NBP data → Clean universe → Returns → De-smoothed returns → Factor signals → Covariance → Optimisation → Backtest

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ncfs.config import StrategyConfig
from ncfs.backtest import run_backtest
from ncfs.evaluation import performance_summary

sns.set_theme(style="whitegrid")
pd.set_option("display.float_format", "{:.4f}".format)

# %% [markdown]
# ## 1. Configuration
#
# All hyperparameters are centralised in `StrategyConfig`. Modify values here before running.

# %%
cfg = StrategyConfig(
    lam=10.0,
    gamma_rated=0.0025,
    gamma_unrated=0.0075,
    burn_in_months=36,
)
print(cfg)

# %% [markdown]
# ## 2. Run backtest
#
# The `run_backtest()` function executes the full walk-forward pipeline.
# Before running, ensure your data files are placed in `data/raw/` with the schemas documented in `ncfs.data_loader`.

# %%
# result = run_backtest(cfg)
# Uncomment the line above once data files are in place

# %% [markdown]
# ## 3. Performance summary

# %%
# summary = performance_summary(result)
# summary

# %% [markdown]
# ## 4. Cumulative returns

# %%
# df = result.to_dataframe()
# cum_gross = (1 + df["gross_return"]).cumprod()
# cum_net = (1 + df["net_return"]).cumprod()
#
# fig, ax = plt.subplots(figsize=(12, 5))
# cum_gross.plot(ax=ax, label="Gross")
# cum_net.plot(ax=ax, label="Net of TC")
# ax.set_title("Cumulative Returns")
# ax.set_ylabel("Growth of 1 SEK")
# ax.legend()
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Turnover and universe size

# %%
# fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
#
# df["turnover"].plot(ax=axes[0], title="Monthly Turnover")
# axes[0].set_ylabel("Two-sided turnover")
#
# df["n_bonds"].plot(ax=axes[1], title="Universe Size")
# axes[1].set_ylabel("Number of bonds")
#
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 6. Sensitivity analysis
#
# Run the backtest with different parameter values to assess robustness.

# %%
# sensitivity_results = {}
# for lam in [2, 5, 10, 20, 50]:
#     cfg_s = StrategyConfig(lam=lam)
#     res = run_backtest(cfg_s)
#     summary = performance_summary(res)
#     sensitivity_results[f"lambda={lam}"] = summary["Value"]
#
# pd.DataFrame(sensitivity_results)
